# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
data=pd.read_excel("/content/EmpDetails_2.xlsx")
data
# Out:
#     empno     empname  empsal  empdeptno  emppf  emphra  emplta  empexp
# 0       1       Laxmi     Low         30  0.140   12000   20000       1
# 1       2        Teja     Low         20  0.120   13000   25000       2
# 2       3     Hemanth    High         21  0.150   14000   26000       4
# 3       4         Sai     Low         30  0.210   12600   30000       1
# 4       5      Nehath  Medium          2  0.150   12559   25000       3
# 5       6    Praneeth     Low          1  0.140   14000   25000       2
# 6       7       Divya     Low         15  0.148   15000   27000       1
# 7       8     Deepthi    High         17  0.130   19000   27800       5
# 8       9         Sri    High         19  0.140   15000   27000       4
# 9      10     Krishna    High         16  0.120   18000   20000       5
# 10     11    Yaswanth     Low         22  0.160   14000   22000       2
# 11     12    Prasanth  Medium         28  0.150   16000   20000       3
# 12     13    Mahidhar    High          3  0.160   15400   35000       4
# 13     14        Banu    High         12  0.120   18000   25000       5
# 14     15     Indhira  Medium          2  0.130   14600   30000       3
# 15     16       Priya     Low          7  0.150   18000   20000       1
# 16     17  Pravallika     Low          8  0.140   17000   35000       2
# 17     18     Dharani  Medium          5  0.150   16800   36000       3
# 18     19        Rama  Medium          4  0.140   17400   38000       3
# 19     20       Pavan     Low          9  0.140   20000   28000       2
# 20     21      Pavani    High          5  0.140   19000   25000       5
# 21     22      Harika    High          6  0.120   18000   24000       4
# 22     23     Harnika    High          9  0.120   18400   24000       4
# 23     24      Komali    High          1  0.130   17000   23000       4
# 24     25     Sravani  Medium         15  0.150   15700   20000       3
# 25     26      Kriran    High         15  0.120   15600   21000       5
# 26     27       Vamsi     Low         12  0.150   15700   21000       2
# 27     28      Charan    High         17  0.130   18700   24000       5
# 28     29      Sruthi    High         19  0.120   15700   20000       4
# 29     30     Apoorva     Low         13  0.140   18600   28000       2
# 30     31      Bhoomi     Low         30  0.150   15370   20000       2
# 31     32      Renuka    High         25  0.160   18500   29000       4
# 32     33     Sriteja  Medium         29  0.140   19000   30000       3
# 33     34  Srikrishna     Low         28  0.130   18900   27000       2
# 34     35      Kedhar     Low         27  0.140   18750   26000       1
# 35     36     Kalyani     Low         24  0.150   15000   20000       2
# 36     37     Bhavana  Medium         25  0.180   15470   22000       3
# 37     39      Taruni     Low         26  0.170   17500   27000       2
# 38     40       Tarun    High         12  0.160   20000   32000       4
# 39     41     Gowtham     Low         16  0.120   20000   31500       1
# 40     42     Nandhan    High          1  0.130   20000   32000       4
# 41     43    Srikanth     Low          7  0.140   19500   29100       2
# 42     44     Ashwini    High         18  0.130   19700   29800       4
# 43     45       Rekha    High          9  0.140   18000   28100       5
# 44     46   Manikanta    High          7  0.150   17990   26500       5
# 45     47      Sruthi  Medium          4  0.140   15000   25000       3
# 46     48       Gopal     Low          3  0.160   19000   30000       2
# 47     49     Keerthi    High         11  0.170   20000   31000       5
# 48     50      Anusha  Medium          1  0.180   19000   30000       3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   empno      49 non-null     int64
#  1   empname    49 non-null     object
#  2   empsal     49 non-null     object
#  3   empdeptno  49 non-null     int64
#  4   emppf      49 non-null     float64
#  5   emphra     49 non-null     int64
#  6   emplta     49 non-null     int64
#  7   empexp     49 non-null     int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 3.2+ KB

# %%
data.head(3)
# Out:
#    empno  empname empsal  empdeptno  emppf  emphra  emplta  empexp
# 0      1    Laxmi    Low         30   0.14   12000   20000       1
# 1      2     Teja    Low         20   0.12   13000   25000       2
# 2      3  Hemanth   High         21   0.15   14000   26000       4

# %%
data.tail(6)
# Out:
#     empno    empname  empsal  empdeptno  emppf  emphra  emplta  empexp
# 43     45      Rekha    High          9   0.14   18000   28100       5
# 44     46  Manikanta    High          7   0.15   17990   26500       5
# 45     47     Sruthi  Medium          4   0.14   15000   25000       3
# 46     48      Gopal     Low          3   0.16   19000   30000       2
# 47     49    Keerthi    High         11   0.17   20000   31000       5
# 48     50     Anusha  Medium          1   0.18   19000   30000       3

# %%
x = data[['empexp']]  # Independent variable
y = data['empsal']        # Dependent variable

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rand = RandomForestClassifier(random_state=42)
rand.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rand.predict(x_test)

# %%
y_pred
# Out:
# array(['High', 'Medium', 'High', 'High', 'Medium', 'High', 'Low', 'High',
#        'High', 'Low'], dtype=object)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the model: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the model: 100.00%
